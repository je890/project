# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.dates as mdates
from datetime import datetime
import peakutils 
import cv2


filenames = ['ERC_data_04_23_2019.txt','ERC_data_04_22_2019.txt','ERC_data_04_15_2019.txt',
             'ERC_data_04_12_2019.txt','ERC_data_04_11_2019.txt', 'ERC_data_04_05_2019.txt','ERC_data_04_03_2019.txt',
             'ERC_data_03_21_2019.txt','ERC_data_03_14_2019.txt']

with open("Combined_data.txt", 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())

# %%
with open('Combined_data.txt', 'rb') as file_in:
    with open("Filter_Data.txt", "wb") as file_out:
        file_out.writelines(filter(lambda line: b'GMT' in line, file_in))

# %%
df = pd.read_csv("Filter_Data.txt", header=None)
df[5] = df[1]*df[4]
df.drop(df.columns[[1,2,3,4]], axis=1, inplace=True)
new = df[0].str.split(" ", n = 1, expand = True) 
df[6] = new[1]
df['DateTime'] = pd.to_datetime(df[6], infer_datetime_format = True)
date_index = pd.DatetimeIndex(df['DateTime'])
df.set_index('DateTime', drop=True, append=False, inplace=True,verify_integrity=False)
df = df.sort_index()
del df[0]
del df[6]

df.columns = ['Power']

# %%
import pandas as pd
import re
df = pd.read_csv("uncleaned_prereq_cs.csv",header=None)
df['Course Name'] = df[0]
df['Prereq'] = df[1]
del df[0]
del df[1]
df1 = df['Prereq'].str.split(" ", expand = True)
df1
# Out:
#          0       1         2     3           4         5            6   \
# 0       NaN     NaN       NaN   NaN         NaN       NaN          NaN
# 1       NaN     NaN       NaN   NaN         NaN       NaN          NaN
# 2       NaN     NaN       NaN   NaN         NaN       NaN          NaN
# 3   Prereq:      At     least   90%          in        CS          115
# 4   Prereq:      CS       145  with           a     grade           of
# 5   Prereq:    MATH       104    or          4U  Calculus          and
# 6   Prereq:      4U  Calculus   and    Vectors.      None         None
# 7   Prereq:      4U  Calculus   and    Vectors;   Honours  Mathematics
# 8   Prereq:     One        of  MATH        117,      127,         137,
# 9   Prereq:   (MATH       116    or         117        or          127
# 10  Prereq:    MATH       147    or  instructor  consent;      Honours
# 11  Prereq:      4U  Calculus   and     Vectors        or           4U
# ...

# %%
s1 = ["CS","MATH","STAT"]
import re
df1.fillna("none", inplace=True)
df2 = df
for index, row in df1.iterrows():
    s2 = []
    bracketappear = False
    for i in range(0,length):
        if row[i] in s1:
            title = row[i]
            start = i
            while True:
                start = start + 1
                if "," in row[start]:
                    temp = title + row[start]
                    s2.append(temp)
                else:
                    temp = title + row[start]
                    s2.append(temp)
                    break;
        elif "(" in row[i]:
            title = row[i][1:]
            temp = title + row[i+1]
            bracketappear = True
            s2.append(temp)
        elif row[i] == "One":
            title = row[i+2]
            num = row[i+3]
            temp = title + num
            s2.append(temp)
        elif bracketappear == False and row[i] == "or":
            title = row[i-2]
            num = row[i-1]
            temp = title + num
            s2.append(temp)
        print(s2)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['CS145']
# []
# ['MATH104']
# []
# []
# []
# []
# []
# ['MATH117,']
# []
# ['MATH116']
# []
# ['MATH147']
# []
# []
# []
# []
# []
# ['MATH135']
# []
# ['MATH145']
# []
# ['(MATH106']
# []
# ['MATH135']
# []
# ['MATH135']
# []
# ['MATH137']
# []
# ['MATH119']
# []
# ['MATH138/148']
# []
# ['CS245']
# []
# ['CS138']
# []
# ['Oneof']
# []
# ['CS146']
# []
# ['CS136,']
# []
# ['CS240']
# []
# ['CS240,', 'CS241,', 'CS246,', 'CS(CS']
# []
# ['MATH135']
# []
# []
# []
# ['STAT341']

# %%
      while True:
                start = start + 1
                if strn.find(",") == -1:
                    temp = title + row[start]
                    s2.append(temp)
                else:
                    temp = title + row[start]
                    s2.append(temp)
                    break;
    
    elif row[pos].str.contains("("):
            if row[i+2] == "or":
                title = row[i].slice(start=1)
                temp = title + row[i+1]
                s2.append(temp)
                
                 title = row[i][1:]
                temp = title + row[i+1]
                s2.append(temp)

# %%
filenames = ['ERC_data_04_25_2019_1.txt','ERC_data_04_25_2019.txt','ERC_data_04_26_2019.txt','ERC_data_04_27_2019.txt','ERC_data_04_28_2019.txt',
             'ERC_data_04_29_2019.txt', 'ERC_data_05_01_2019.txt', 'ERC_data_05_02_2019.txt','ERC_data_05_03_2019.txt','ERC_data_05_04_2019.txt',
            'ERC_data_05_05_2019.txt','ERC_data_05_06_2019.txt','ERC_data_05_07_2019.txt','ERC_data_05_08_2019.txt',
             'ERC_data_05_09_2019.txt','ERC_data_05_10_2019.txt','ERC_data_05_11_2019.txt','ERC_data_05_12_2019.txt',
            'ERC_data_05_13_2019.txt','ERC_data_05_14_2019.txt','ERC_data_05_15_2019.txt',
            'ERC_data_05_16_2019.txt', 'ERC_data_05_17_2019.txt','ERC_data_05_18_2019.txt','ERC_data_05_19_2019.txt', 'ERC_data_05_20_2019.txt',
            'Data.20190521.txt','Data.20190522.txt','Data.20190523.txt','Data.20190524.txt','Data.20190525.txt','Data.20190526.txt','Data.20190527.txt',
             'Data.20190528.txt','Data.20190529.txt','Data.20190530.txt','Data.20190531.txt','Data.20190601.txt',
'Data.20190602.txt','Data.20190603.txt','Data.20190604.txt','Data.20190611.txt','Data.20190617.txt','Data.20190618.txt','Data.20190619.txt','Data.20190620.txt','Data.20190621.txt'
            ,'Data.20190622.txt','Data.20190623.txt','Data.20190624.txt','Data.20190625.txt','Data.20190626.txt','Data.20190627.txt','Data.20190628.txt','Data.20190701.txt','Data.20190702.txt','Data.20190703.txt',
             'Data.20190704.txt','Data.20190705.txt','Data.20190706.txt','Data.20190707.txt','Data.20190710.txt','Data.20190711.txt','Data.20190716.txt','Data.20190717.txt','Data.20190718.txt','Data.20190719.txt',
             'Data.20190720.txt','Data.20190721.txt','Data.20190721.txt','Data.20190722.txt']
             
with open("Combined_data1.txt", 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())

# %%
with open('Combined_data1.txt', 'rb') as file_in:
    with open("Filter_Data1.txt", "wb") as file_out:
        file_out.writelines(filter(lambda line: b'GMT' in line, file_in))
        
df1 = pd.read_csv("Filter_Data1.txt", header=None)
df1[4] = df1[1]*df1[3]
df1.drop(df1.columns[[1,2,3]], axis=1, inplace=True)
new = df1[0].str.split(" ", n = 1, expand = True) 
df1[6] = new[1]
df1['DateTime'] = pd.to_datetime(df1[6], infer_datetime_format = True)
date_index = pd.DatetimeIndex(df1['DateTime'])
df1.set_index('DateTime', drop=True, append=False, inplace=True, verify_integrity=False)
df1 = df1.sort_index()
del df1[0]
del df1[6]
df1.columns = ['Power']

# %%
combine = pd.concat([df, df1], ignore_index=False)
combine = combine.resample('10min').mean()
combine.to_csv('May Data.csv')

# %%
import imageio
f = imageio.imread('2019-05-20_15-46-00_668.jpg', as_gray=True)

def img_estim(img, thrshld):
    is_light = np.mean(img) > thrshld
    return 'light' if is_light else 'dark'

print(img_estim(f, 130))
# Out:
# dark

# %%
import pandas as pd
import os
import csv
import cv2
import glob
import numpy as np
os.path.splitext("path_to_file")[0]

img_dir = "/Users/mac/Desktop/New folder-2/" 
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)
data = {}
for f1 in files:
    img = cv2.imread(f1)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    average_color_per_row = np.average(gray, axis=0)
    average_color = np.average(average_color_per_row, axis=0)
    average_color = np.uint8(average_color)
    data[os.path.splitext(f1)[0]] = average_color


    
with open('cloudy.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in data.items():
       writer.writerow([key, value])

# %%
import cv2
import pandas as pd
import os
import csv
import argparse
import glob
import numpy as np
img_dir = "/Users/mac/Downloads/save/" 
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)
data= {}
for f1 in files:
    img = cv2.imread(f1)
    n_white_pix = np.sum(img == 0)

    dimensions = img.shape

    # height, width, number of channels in image
    height = img.shape[0]
    width = img.shape[1]
    total = height*width
    
    data[os.path.splitext(f1)[0]] = n_white_pix/total
    
with open('shadows.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in data.items():
       writer.writerow([key, value])

# %%
im = cv2.imread("image.jpg")
     
    # Select ROI
r = cv2.selectROI(im)
     
    # Crop image
imCrop = im[int(r[1]):int(r[1]+r[3]), int(r[0]):int(r[0]+r[2])]
 
    # Display cropped image
cv2.imshow("Image", imCrop)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-25-aad5ba68c69e> in <module>
#       2
#       3     # Select ROI
# ----> 4 r = cv2.selectROI(im)
#       5
#       6     # Crop image
#
# error: OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/highgui/src/window.cpp:356: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
import numpy as np
import cv2

image = cv2.imread('2019-07-07_18-51-45_843.jpg')
crop = image[430:800, 210:910]
cv2.imwrite('modify.jpg', crop)
# Out:
# True

# %%
import numpy as np
import cv2
import pandas as pd
import os
import csv
import glob
os.path.splitext("path_to_file")[0]

img_dir = "/Users/mac/Desktop/New folder/" 
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)
data = {}
for f1 in files:
    image = cv2.imread(f1, cv2.IMREAD_GRAYSCALE)
    crop = image[430:800, 210:910]
    n_white_pix = np.sum(crop == 0)
    height = crop.shape[0]
    width = crop.shape[1]
    total = height*width
    data[os.path.splitext(f1)[0]] = n_white_pix/total
    
with open('shadows2.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in data.items():
       writer.writerow([key, value])
